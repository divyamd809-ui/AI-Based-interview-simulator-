# %% [markdown]
# <a href="https://colab.research.google.com/github/divyamd809-ui/AI-Based-interview-simulator-/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = input("Enter a string: ")

reverse = ""

for i in s:
    reverse = i + reverse

print("Reversed string:", reverse)
