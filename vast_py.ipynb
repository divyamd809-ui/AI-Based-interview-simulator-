# %% [markdown]
# <a href="https://colab.research.google.com/github/divyamd809-ui/AI-Based-interview-simulator-/blob/main/vast_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s=input("Ënter a string:")
s1=""
for i in s:
  if(i!=" "):
    s1+=i
print(s1)
# Out:
# Ënter a string:amma
# amma

# %%
a = []
b = []
N1 = int(input("enter the value of N1:"))
N2 = int(input("enter the value of N2:"))
a = list(map(int, input("Enter the elements: ").split()))
b = list(map(int, input("Enter the elements: ").split()))
c = a + b
c = list(set(c))
c.sort()
n = len(c)
if n % 2 == 1:
print("op=", c[n // 2])
else:
median = (c[n // 2 - 1] + c[n // 2]) / 2
print("op=", median)
# Out:
#   File "/tmp/ipykernel_3250/2571168307.py", line 12
#     print("op=", c[n // 2])
#     ^
# IndentationError: expected an indented block after 'if' statement on line 11

# %%
a=input("Enter your string:")
vow=0
cons=0
for char in a:
  if char=='a' or char=='i' or char=='o' or char=='e' or char=='u' or char=='A' or char=='E' or char=='I' or char=='O' or char=='U':
    vow=vow+1
  else:
    cons=cons+1
print("count of vowels:",vow)
print("count of consonents:",cons)
# Out:
# Enter your string:abseiou
# count of vowels: 5
# count of consonents: 2
